# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("C:/Users/Lenowo/Downloads/movie_metadata/movie_metadata.csv")
df.head(20)
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 4     NaN        Doug Walker                     NaN       NaN
# 5   Color     Andrew Stanton                   462.0     132.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8   Color        Joss Whedon                   635.0     141.0
# 9   Color        David Yates                   375.0     153.0
# 10  Color        Zack Snyder                   673.0     183.0
# 11  Color       Bryan Singer                   434.0     169.0
# 12  Color       Marc Forster                   403.0     106.0
# 13  Color     Gore Verbinski                   313.0     151.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
numbers =df._get_numeric_data()
numbers.columns
# Out:
# Index(['num_critic_for_reviews', 'duration', 'director_facebook_likes',
#        'actor_3_facebook_likes', 'actor_1_facebook_likes', 'gross',
#        'num_voted_users', 'cast_total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'actor_2_facebook_likes', 'imdb_score', 'aspect_ratio',
#        'movie_facebook_likes'],
#       dtype='object')

# %%
def crt(x):
    mean= round(x.mean(),2)
    return mean
vals = crt(df['num_critic_for_reviews'])
print(vals)
# Out:
# 140.19

# %%
df['num_critic_for_reviews']=df['num_critic_for_reviews'].fillna(140.19)

# %%
vals = crt(df['duration'])
print(vals)
# Out:
# 107.2

# %%
df['duration']=df['duration'].fillna(107.2)

# %%
vals = crt(df['director_facebook_likes'])
print(vals)
# Out:
# 686.51

# %%
df['director_facebook_likes']=df['director_facebook_likes'].fillna(673.36)

# %%
vals = crt(df['actor_3_facebook_likes'])
print(vals)
# Out:
# 645.01

# %%
df['actor_3_facebook_likes']=df['actor_3_facebook_likes'].fillna(645.01)

# %%
vals=crt(df['actor_1_facebook_likes'])
print(vals)
# Out:
# 6560.05

# %%
df['actor_1_facebook_likes']=df['actor_1_facebook_likes'].fillna(6560.05)

# %%
vals=crt(df['gross'])
print(vals)
# Out:
# 48468407.53

# %%
df['gross']=df['gross'].fillna(48468407.53)

# %%
vals=crt(df['facenumber_in_poster'])
print(vals)
# Out:
# 1.37

# %%
df['facenumber_in_poster']=df['facenumber_in_poster'].fillna(1.37)

# %%
vals=crt(df['num_user_for_reviews'])
print(vals)
# Out:
# 272.77

# %%
df['num_user_for_reviews']=df['num_user_for_reviews'].fillna(272.77)

# %%
vals=crt(df['budget'])
print(vals)
# Out:
# 39752620.44

# %%
df['budget']=df['budget'].fillna(39752620.44)

# %%
vals = crt(df['title_year'])
print(vals)
# Out:
# 2002.47

# %%
df['title_year']=df['title_year'].fillna(2002.47)

# %%
vals= crt(df['actor_2_facebook_likes'])
print(vals)
# Out:
# 1651.75

# %%
df['actor_2_facebook_likes']=df['actor_2_facebook_likes'].fillna(1651.75)

# %%
vals=crt(df['aspect_ratio'])
print(vals)
# Out:
# 2.22

# %%
df['aspect_ratio']=df['aspect_ratio'].fillna(2.22)

# %%
# how to get non_numeric values for the df.

non_numbers=df.select_dtypes(include=np.object)
no_numbers=non_numbers.columns.to_list()
no_numbers
# Out:
# <ipython-input-246-6a676c3959ed>:3: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   non_numbers=df.select_dtypes(include=np.object)
# ['color',
#  'director_name',
#  'actor_2_name',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'actor_3_name',
#  'plot_keywords',
#  'movie_imdb_link',
#  'language',
#  'country',
#  'content_rating']

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews         0
# duration                       0
# director_facebook_likes        0
# actor_3_facebook_likes         0
# actor_2_name                  13
# actor_1_facebook_likes         0
# gross                          0
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster           0
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews           0
# language                      12
# country                        5
# content_rating               303
# budget                         0
# title_year                     0
# actor_2_facebook_likes         0
# imdb_score                     0
# aspect_ratio                   0
# movie_facebook_likes           0
# dtype: int64

# %%
# checking for missing and NaN values for non-numeric.

df['color'].unique()
# Out:
# array(['Color', nan, ' Black and White'], dtype=object)

# %%
df['color']=df['color'].fillna('color')
df['color']
# Out:
# 0       Color
# 1       Color
# 2       Color
# 3       Color
# 4       color
#         ...
# 5038    Color
# 5039    Color
# 5040    Color
# 5041    Color
# 5042    Color
# Name: color, Length: 5043, dtype: object

# %%
df['director_name'].unique()
# Out:
# array(['James Cameron', 'Gore Verbinski', 'Sam Mendes', ...,
#        'Scott Smith', 'Benjamin Roberds', 'Daniel Hsia'], dtype=object)

# %%
df['director_name']=df['director_name'].fillna('missing')
df['director_name']
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 5038          Scott Smith
# 5039              missing
# 5040     Benjamin Roberds
# 5041          Daniel Hsia
# 5042             Jon Gunn
# Name: director_name, Length: 5043, dtype: object

# %%
df['actor_2_name']=df['actor_2_name'].fillna('missing')
df['actor_2_name']
# Out:
# 0       Joel David Moore
# 1          Orlando Bloom
# 2           Rory Kinnear
# 3         Christian Bale
# 4             Rob Walker
#               ...
# 5038       Daphne Zuniga
# 5039       Valorie Curry
# 5040       Maxwell Moody
# 5041       Daniel Henney
# 5042    Brian Herzlinger
# Name: actor_2_name, Length: 5043, dtype: object

# %%
df['actor_1_name']=df['actor_1_name'].fillna('missing')
df['actor_1_name']
# Out:
# 0           CCH Pounder
# 1           Johnny Depp
# 2       Christoph Waltz
# 3             Tom Hardy
# 4           Doug Walker
#              ...
# 5038        Eric Mabius
# 5039        Natalie Zea
# 5040        Eva Boehnke
# 5041          Alan Ruck
# 5042        John August
# Name: actor_1_name, Length: 5043, dtype: object

# %%
df['actor_3_name']=df['actor_3_name'].fillna('missing')
df['actor_3_name']
# Out:
# 0                  Wes Studi
# 1             Jack Davenport
# 2           Stephanie Sigman
# 3       Joseph Gordon-Levitt
# 4                    missing
#                 ...
# 5038            Crystal Lowe
# 5039           Sam Underwood
# 5040          David Chandler
# 5041             Eliza Coupe
# 5042                Jon Gunn
# Name: actor_3_name, Length: 5043, dtype: object

# %%
df['plot_keywords']=df['plot_keywords'].fillna('missing')
df['plot_keywords']
# Out:
# 0                  avatar|future|marine|native|paraplegic
# 1       goddess|marriage ceremony|marriage proposal|pi...
# 2                     bomb|espionage|sequel|spy|terrorist
# 3       deception|imprisonment|lawlessness|police offi...
# 4                                                 missing
#                               ...
# 5038               fraud|postal worker|prison|theft|trial
# 5039         cult|fbi|hideout|prison escape|serial killer
# 5040                                              missing
# 5041                                              missing
# 5042    actress name in title|crush|date|four word tit...
# Name: plot_keywords, Length: 5043, dtype: object

# %%
df['language']=df['language'].fillna('missing')
df['language']
# Out:
# 0       English
# 1       English
# 2       English
# 3       English
# 4       missing
#          ...
# 5038    English
# 5039    English
# 5040    English
# 5041    English
# 5042    English
# Name: language, Length: 5043, dtype: object

# %%
df['country']=df['country'].fillna('missing')
df['country']
# Out:
# 0           USA
# 1           USA
# 2            UK
# 3           USA
# 4       missing
#          ...
# 5038     Canada
# 5039        USA
# 5040        USA
# 5041        USA
# 5042        USA
# Name: country, Length: 5043, dtype: object

# %%
df['content_rating']=df['content_rating'].fillna('missing')
df['content_rating']
# Out:
# 0         PG-13
# 1         PG-13
# 2         PG-13
# 3         PG-13
# 4       missing
#          ...
# 5038    missing
# 5039      TV-14
# 5040    missing
# 5041      PG-13
# 5042         PG
# Name: content_rating, Length: 5043, dtype: object

# %%
df.head(20)
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                  723.00     178.0
# 1   Color     Gore Verbinski                  302.00     169.0
# 2   Color         Sam Mendes                  602.00     148.0
# 3   Color  Christopher Nolan                  813.00     164.0
# 4   color        Doug Walker                  140.19     107.2
# 5   Color     Andrew Stanton                  462.00     132.0
# 6   Color          Sam Raimi                  392.00     156.0
# 7   Color       Nathan Greno                  324.00     100.0
# 8   Color        Joss Whedon                  635.00     141.0
# 9   Color        David Yates                  375.00     153.0
# 10  Color        Zack Snyder                  673.00     183.0
# 11  Color       Bryan Singer                  434.00     169.0
# 12  Color       Marc Forster                  403.00     106.0
# 13  Color     Gore Verbinski                  313.00     151.0
# ...

# %%
df.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64
