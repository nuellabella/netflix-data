# %%
import pandas as dp
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
df = dp.read_csv("C:/Users/Lenowo/Downloads/International_Breweries.csv")
df.head()
# Out:
#    SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0     10101   Jardine       jard@gmail.com       trophy         150
# 1     10102      Gill      gillhell@uk.com    budweiser         250
# 2     10103   Sorvino  sorvi2000@gmail.com  castle lite         180
# 3     10104     Jones    jone.ai@yahoo.com  eagle lager         170
# 4     10105   Andrews       andy@gmail.com         hero         150
#
#    UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES  ... Unnamed: 13  \
# 0         200       725  145000   36250     Ghana  ...         NaN
# 1         500       815  407500  203750   Nigeria  ...         NaN
# 2         450       937  421650  252990      Togo  ...         NaN
# 3         250       765  191250   61200     Benin  ...         NaN
# 4         200       836  167200   41800   Senegal  ...         NaN
#
#   Unnamed: 14  Unnamed: 15  Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# ...

# %%
gh= df[(df.YEARS==2019)]
gh
# Out:
#       SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0        10101   Jardine       jard@gmail.com       trophy         150
# 5        10106   Jardine       jard@gmail.com    beta malt          80
# 8        10109    Morgan   morganny@gmail.com    budweiser         250
# 11       10112     Jones    jone.ai@yahoo.com         hero         150
# 15       10116     Jones    jone.ai@yahoo.com    budweiser         250
# ...        ...       ...                  ...          ...         ...
# 1035     11136    Morgan   morganny@gmail.com   grand malt          90
# 1037     11138   Sorvino  sorvi2000@gmail.com    budweiser         250
# 1040     11141  Thompson         thomp@uk.com         hero         150
# 1044     11145   Andrews       andy@gmail.com    budweiser         250
# 1046     11147    Morgan   morganny@gmail.com  eagle lager         170
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES  ... Unnamed: 13  \
# ...

# %%
count= df.groupby("COUNTRIES")["PROFIT"].sum().sort_values(ascending=False)
count

# %%
f = gh.groupby("COUNTRIES")["PROFIT"].sum().sort_values(ascending = False)
f
# Out:
# COUNTRIES
# Ghana      7144070
# Senegal    6687560
# Togo       6109960
# Benin      5273340
# Nigeria    4805320
# Name: PROFIT, dtype: int64

# %%
df18 = df[(df.YEARS==2018) & (df.MONTHS== "December")]
df18
# Out:
#       SALES_ID SALES_REP                    EMAILS       BRANDS  PLANT_COST  \
# 71       10172     Jones         jone.ai@yahoo.com    budweiser         250
# 95       10196   Sorvino       sorvi2000@gmail.com         hero         150
# 107      10208   Jardine            jard@gmail.com  castle lite         180
# 179      10280    Morgan        morganny@gmail.com         hero         150
# 191      10292    Kivell        kivel_go@yahoo.com  castle lite         180
# 203      10304     Jones         jone.ai@yahoo.com       trophy         150
# 239      10340   Andrews            andy@gmail.com    budweiser         250
# 287      10388    Kivell        kivel_go@yahoo.com       trophy         150
# 299      10400   Sorvino       sorvi2000@gmail.com    beta malt          80
# 335      10436    Morgan        morganny@gmail.com   grand malt          90
# 359      10460   Jardine            jard@gmail.com  castle lite         180
# ...

# %%
df18min = df18["PROFIT"].min()
df18min
# Out:
# 38150

# %%
df18["MONTHS"].unique()
# Out:
# array(['December'], dtype=object)

# %%
df.columns
# Out:
# Index(['SALES_ID', 'SALES_REP', 'EMAILS', 'BRANDS', 'PLANT_COST', 'UNIT_PRICE',
#        'QUANTITY', 'COST', 'PROFIT', 'COUNTRIES', 'REGION ', 'MONTHS', 'YEARS',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
df['COUNTRIES'].unique()
# Out:
# array(['Ghana', 'Nigeria', 'Togo', 'Benin', 'Senegal'], dtype=object)

# %%
anglo_data=df[(df.COUNTRIES=='Nigeria')|(df.COUNTRIES=='Ghana')]

# %%
franco_data=df[(df.COUNTRIES=='Togo')|(df.COUNTRIES=='Benin')|(df.COUNTRIES=='Senegal')]

# %%
df['BRANDS'].unique()
# Out:
# array(['trophy', 'budweiser', 'castle lite', 'eagle lager', 'hero',
#        'beta malt', 'grand malt'], dtype=object)

# %%
df['MONTHS'].unique
# Out:
# <bound method Series.unique of 0        January
# 1       February
# 2          March
# 3          April
# 4            May
#           ...
# 1042    November
# 1043    December
# 1044     January
# 1045    February
# 1046       March
# Name: MONTHS, Length: 1047, dtype: object>

# %%
#profit worth of the breweries
df['PROFIT'].sum()
# Out:
# 105587420

# %%
anglo_data['PROFIT'].sum()
# Out:
# 42389260

# %%
franco_data['PROFIT'].sum()
# Out:
# 63198160

# %%
def count_high_profit(country,year):
    x= df['PROFIT']
    b= 0
    for i in df['PROFIT']:
        if i>b:
            b=i

# %%
count= df.groupby("COUNTRIES")["PROFIT"].sum().sort_values(ascending=False)
count
# Out:
# COUNTRIES
# Senegal    21485190
# Nigeria    21376210
# Ghana      21013050
# Benin      20961970
# Togo       20751000
# Name: PROFIT, dtype: int64

# %%
twenty19 = df[(df.YEARS==2019)]
twenty19
# Out:
#       SALES_ID SALES_REP               EMAILS       BRANDS  PLANT_COST  \
# 0        10101   Jardine       jard@gmail.com       trophy         150
# 5        10106   Jardine       jard@gmail.com    beta malt          80
# 8        10109    Morgan   morganny@gmail.com    budweiser         250
# 11       10112     Jones    jone.ai@yahoo.com         hero         150
# 15       10116     Jones    jone.ai@yahoo.com    budweiser         250
# ...        ...       ...                  ...          ...         ...
# 1035     11136    Morgan   morganny@gmail.com   grand malt          90
# 1037     11138   Sorvino  sorvi2000@gmail.com    budweiser         250
# 1040     11141  Thompson         thomp@uk.com         hero         150
# 1044     11145   Andrews       andy@gmail.com    budweiser         250
# 1046     11147    Morgan   morganny@gmail.com  eagle lager         170
#
#       UNIT_PRICE  QUANTITY    COST  PROFIT COUNTRIES        REGION   \
# ...

# %%
cwhp19= twenty19.groupby("COUNTRIES")["PROFIT"].sum().sort_values(ascending=False)
cwhp19
# Out:
# COUNTRIES
# Ghana      7144070
# Senegal    6687560
# Togo       6109960
# Benin      5273340
# Nigeria    4805320
# Name: PROFIT, dtype: int64

# %%
total19=twenty19["PROFIT"].sum()
total19
# Out:
# 30020250

# %%
new_count= count.reset_index()
new_count
# Out:
#   COUNTRIES    PROFIT
# 0   Senegal  21485190
# 1   Nigeria  21376210
# 2     Ghana  21013050
# 3     Benin  20961970
# 4      Togo  20751000

# %%
plt.title("Countries by Profit")
plt.pie(new_count["PROFIT"], labels=new_count["COUNTRIES"],autopct='%1.1f%%')
plt.show()

# %%
df['BRANDS'].unique()
# Out:
# array(['trophy', 'budweiser', 'castle lite', 'eagle lager', 'hero',
#        'beta malt', 'grand malt'], dtype=object)

# %%
df.columns
# Out:
# Index(['SALES_ID', 'SALES_REP', 'EMAILS', 'BRANDS', 'PLANT_COST', 'UNIT_PRICE',
#        'QUANTITY', 'COST', 'PROFIT', 'COUNTRIES', 'REGION ', 'MONTHS',
#        'YEARS'],
#       dtype='object')

# %%
df['REGION '].unique()
# Out:
# array(['Southeast', 'west', 'southsouth', 'northwest', 'northeast ',
#        'northcentral '], dtype=object)
