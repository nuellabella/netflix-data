# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("C:/Users/Lenowo/Desktop/archive/supermarket_sales - Sheet1.csv")
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   01-05-19
# 1  Electronic accessories       15.28         5   3.8200   80.2200   03-08-19
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   03-03-19
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   02-08-19
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   01-05-19
# 1  Electronic accessories       15.28         5   3.8200   80.2200   03-08-19
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   03-03-19
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   02-08-19
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#df[["Day", "Month", "year"]] = df["Date"].str.split("/",expand=True)
#agg=df.groupby(['Month'])

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#df["Date"]=pd.to_numeric(df["Date"])

# %%
df["actual_Price"] =(df["Quantity"]) * (df["Unit price"]) 
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#df["Date"].unique()

# %%
len(df)
# Out:
# 1000

# %%
# female_beauty= df[(df.Product line =="Health and beauty")]
# female_beauty

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'actual_Price'],
#       dtype='object')

# %%
df2 = df.rename({'Invoice ID': 'Invoice_ID','Customer type' :'Customer_type','Product line':'Product_line','Unit price':'Unit_price',
                       'Tax 5%':'Tax_5%','gross margin percentage':'gross_margin_percentage','gross income':'gross_income'}, axis="columns")

# %%
df2
# Out:
#       Invoice_ID Branch       City Customer_type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product_line  Unit_price  Quantity   Tax_5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#1.Between male and female who uses more health and beauty products

df3= df2[(df2.Product_line== "Health and beauty") & (df2.Gender=="Female")]
df3
# Out:
#       Invoice_ID Branch       City Customer_type  Gender       Product_line  \
# 0    750-67-8428      A     Yangon        Member  Female  Health and beauty
# 8    665-32-9167      A     Yangon        Member  Female  Health and beauty
# 14   829-34-3910      A     Yangon        Normal  Female  Health and beauty
# 16   656-95-9349      A     Yangon        Member  Female  Health and beauty
# 38   333-73-7901      C  Naypyitaw        Normal  Female  Health and beauty
# ..           ...    ...        ...           ...     ...                ...
# 927  397-25-8725      A     Yangon        Member  Female  Health and beauty
# 936  433-08-7822      C  Naypyitaw        Normal  Female  Health and beauty
# 938  131-70-8179      A     Yangon        Member  Female  Health and beauty
# 968  605-03-2706      A     Yangon        Normal  Female  Health and beauty
# 986  764-44-8999      B   Mandalay        Normal  Female  Health and beauty
#
# ...

# %%
total_female= df3.groupby('Gender')['actual_Price'].sum().sort_values(ascending=False)
total_female[0]
# Out:
# 17677.13

# %%
# tot_female = total_female['actual_Price'].sum()
# tot_female

# %%
df4=df2[(df2.Gender=='Male')& (df2.Product_line=='Health and beauty')]
df4.head(2)
# Out:
#      Invoice_ID Branch      City Customer_type Gender       Product_line  \
# 3   123-19-1176      A    Yangon        Member   Male  Health and beauty
# 21  371-85-5789      B  Mandalay        Normal   Male  Health and beauty
#
#     Unit_price  Quantity  Tax_5%    Total       Date   Time  Payment    cogs  \
# 3        58.22         8  23.288  489.048  1/27/2019  20:33  Ewallet  465.76
# 21       87.98         3  13.197  277.137   03-05-19  10:40  Ewallet  263.94
#
#     gross_margin_percentage  gross_income  Rating  actual_Price
# 3                  4.761905        23.288     8.4        465.76
# 21                 4.761905        13.197     5.1        263.94

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 3 to 995
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice_ID               88 non-null     object
#  1   Branch                   88 non-null     object
#  2   City                     88 non-null     object
#  3   Customer_type            88 non-null     object
#  4   Gender                   88 non-null     object
#  5   Product_line             88 non-null     object
#  6   Unit_price               88 non-null     float64
#  7   Quantity                 88 non-null     int64
#  8   Tax_5%                   88 non-null     float64
#  9   Total                    88 non-null     float64
#  10  Date                     88 non-null     object
#  11  Time                     88 non-null     object
#  12  Payment                  88 non-null     object
#  13  cogs                     88 non-null     float64
# ...

# %%
df4["Date"]=pd.to_datetime(df4["Date"])
# Out:
# <ipython-input-62-07ebd76222f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4["Date"]=pd.to_datetime(df4["Date"])

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 3 to 995
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice_ID               88 non-null     object
#  1   Branch                   88 non-null     object
#  2   City                     88 non-null     object
#  3   Customer_type            88 non-null     object
#  4   Gender                   88 non-null     object
#  5   Product_line             88 non-null     object
#  6   Unit_price               88 non-null     float64
#  7   Quantity                 88 non-null     int64
#  8   Tax_5%                   88 non-null     float64
#  9   Total                    88 non-null     float64
#  10  Date                     88 non-null     datetime64[ns]
#  11  Time                     88 non-null     object
#  12  Payment                  88 non-null     object
#  13  cogs                     88 non-null     float64
# ...

# %%
df4["Day"]=df4["Date"].dt.day
df4["Month"]=df4["Date"].dt.month
df4["Year"]=df4["Date"].dt.year
# Out:
# <ipython-input-64-0c394c29659d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4["Day"]=df4["Date"].dt.day
# <ipython-input-64-0c394c29659d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4["Month"]=df4["Date"].dt.month
# <ipython-input-64-0c394c29659d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df4
# Out:
#       Invoice_ID Branch       City Customer_type Gender       Product_line  \
# 3    123-19-1176      A     Yangon        Member   Male  Health and beauty
# 21   371-85-5789      B   Mandalay        Normal   Male  Health and beauty
# 29   848-62-7243      A     Yangon        Normal   Male  Health and beauty
# 33   595-11-5460      A     Yangon        Normal   Male  Health and beauty
# 44   617-15-4209      C  Naypyitaw        Member   Male  Health and beauty
# ..           ...    ...        ...           ...    ...                ...
# 981  809-46-1866      A     Yangon        Normal   Male  Health and beauty
# 983  148-41-7930      C  Naypyitaw        Normal   Male  Health and beauty
# 987  552-44-5977      B   Mandalay        Member   Male  Health and beauty
# 989  430-53-4718      B   Mandalay        Member   Male  Health and beauty
# 995  233-67-5758      C  Naypyitaw        Normal   Male  Health and beauty
#
# ...

# %%
df4.columns
# Out:
# Index(['Invoice_ID', 'Branch', 'City', 'Customer_type', 'Gender',
#        'Product_line', 'Unit_price', 'Quantity', 'Tax_5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross_margin_percentage', 'gross_income',
#        'Rating', 'actual_Price', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
#df4.drop(["(Day, Month, Year)"], axis="columns", inplace=True)

# %%
male_total = df4.groupby('Gender')['actual_Price'].sum().sort_values(ascending=False)
male_total[0]

# %%
map1 = pd.Series([total_female[0], male_total[0]])
diag = map1.plot(kind= "pie")
#diag.columns=["Gender","map1"]
diag

# %%
map1

# %%
type(map1)

# %%
name = ["female", "male"]
map1.index = name
map1

# %%
df_val = map1.reset_index()
df_val

# %%
df_val.columns = ["sex", "total_score"]

# %%
df_val

# %%
plt.pie(df_val['total_score'], labels=df_val["sex"], autopct="%1.1f%%")
plt.show()

# %%
diag1= df["Gender"].value_count().head().reset_index()
diag1=diag.columns=["Gender","map1"]
diag1

# %%
#2.Male and Female who uses home/lifestyle products.
male_uses_hlp = df2[(df2.Gender== "Male") & (df2.Product_line=='Home and lifestyle')]
male_uses_hlp.head(2)

# %%
male_tot_4hlp = male_uses_hlp.groupby('Gender')['actual_Price'].sum().sort_values(ascending=False)
male_tot_4hlp

# %%
female_uses_hlp = df2[(df2.Gender== "Female") & (df2.Product_line=='Home and lifestyle')]
female_uses_hlp

# %%
Female_tot_4hlp = female_uses_hlp.groupby('Gender')['actual_Price'].sum().sort_values(ascending=False)
Female_tot_4hlp

# %%
#3 In the city of Mandalay, how much quantity of food and beverages was consumed between january to september.
mandalay_food_beverages = df2[(df2.City=='Mandalay') & (df2.Product_line=='Food and beverages')]
mandalay_food_beverages

# %%
jan_sep =mandalay_food_beverages['Date']
jan_sep

# %%
max_date =mandalay_food_beverages['Date'].max()
max_date

# %%
min_date = mandalay_food_beverages['Date'].min()
min_date

# %%
date_val = mandalay_food_beverages[(mandalay_food_beverages.Date >= '01-01-19') & (mandalay_food_beverages.Date <= '3/30/2019')]
date_val

# %%
quant_bev = date_val.groupby('Product_line')['Quantity'].sum().sort_values(ascending=False)
quant_bev

# %%
#4 Which is the most used mode of payment for sport and travel items in Yangon
#md_of_payment = df2[(df2.)]

# %%
df2['Payment'].unique()

# %%
yangon_data = df2[(df2.City=='Yangon') & (df2.Product_line=='Sports and travel')]
yangon_data

# %%
most_ump = yangon_data.groupby('Payment')['actual_Price'].sum().sort_values(ascending=False)
most_ump

# %%
#5 In Yangon which mode of payment is mostly preferred and which sex prefers it most.

# %%
sex_preferred = df2[(df2.City =='Yangon') & (df2.Payment=='Ewallet')]
sex_preferred

# %%
most = sex_preferred.groupby('Gender')['actual_Price'].sum().sort_values(ascending= False)
most
